# %% [markdown]
# # Yetersiz Örnekleme

# %%
# coding: utf-8
# Graphing helper function
def setup_graph(title='', x_label='', y_label='', fig_size=None):
    fig = plt.figure()
    if fig_size != None:
        fig.set_size_inches(fig_size[0], fig_size[1])
    ax = fig.add_subplot(111)
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)

# %%
get_ipython().magic('matplotlib inline')
import matplotlib.pyplot as plt
import numpy as np

t=np.linspace(0,.01,10000, endpoint=False) # ornekleme araligi ornekleyecegimiz frekansin en az iki kati olmali.
ton697Hz=np.sin(2*np.pi*697*t)

setup_graph(x_label=u'Zaman (sn)', y_label=u'Genlik (Voltaj)', title=u'697 Hz ve 103 Hz İşaret (Zaman Alanı)')
plt.plot(t,ton697Hz, 'k');
plt.hold('on')

# Düşük örnekleme hızı ile örneklersek...
t=np.linspace(0,.01,8, endpoint=False); 
plt.stem(t,np.sin(2*np.pi*697*t), linefmt='g--', markerfmt='gx');

# Düşük hızda işaretlenmiş işareti, 103 Hz'lik işaret ile karşılaştıralım
t=np.linspace(0,.01,10000, endpoint=False)
plt.plot(t,np.sin(2*np.pi*103*t+np.pi), 'g--');
plt.show()
